# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
data= pd.read_csv('cardio_values.csv')

test = pd.read_csv('test_values.csv')

# %%
data.describe()
# Out:
#        slope_of_peak_exercise_st_segment  resting_blood_pressure  \
# count                         180.000000              180.000000
# mean                            1.550000              131.311111
# std                             0.618838               17.010443
# min                             1.000000               94.000000
# 25%                             1.000000              120.000000
# 50%                             1.000000              130.000000
# 75%                             2.000000              140.000000
# max                             3.000000              180.000000
#
#        chest_pain_type  num_major_vessels  \
# count       180.000000         180.000000
# mean          3.155556           0.694444
# std           0.938454           0.969347
# min           1.000000           0.000000
# 25%           3.000000           0.000000
# 50%           3.000000           0.000000
# 75%           4.000000           1.000000
# ...

# %%
data.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     0z64un                                  1             normal
# 1     ryoo3j                                  2             normal
# 2     yt1s1x                                  1             normal
# 3     l2xjde                                  1  reversible_defect
# 4     oyt4ek                                  3  reversible_defect
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     128                2                  0
# 1                     110                3                  0
# 2                     125                4                  3
# 3                     152                4                  0
# 4                     178                1                  0
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
test.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     olalu7                                  2  reversible_defect
# 1     z9n6mx                                  1             normal
# 2     5k4413                                  2  reversible_defect
# 3     mrg7q5                                  1             normal
# 4     uki4do                                  2             normal
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     170                1                  0
# 1                     138                4                  0
# 2                     120                4                  0
# 3                     102                3                  1
# 4                     138                4                  1
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
data['max_heart_rate_diff'] = data['max_heart_rate_achieved'] - (data['max_heart_rate_achieved'] - data['age'])

# %%
test['max_heart_rate_diff'] = test['max_heart_rate_achieved'] - (test['max_heart_rate_achieved'] - test['age'])

# %%
test.head()
# Out:
#   patient_id  slope_of_peak_exercise_st_segment               thal  \
# 0     olalu7                                  2  reversible_defect
# 1     z9n6mx                                  1             normal
# 2     5k4413                                  2  reversible_defect
# 3     mrg7q5                                  1             normal
# 4     uki4do                                  2             normal
#
#    resting_blood_pressure  chest_pain_type  num_major_vessels  \
# 0                     170                1                  0
# 1                     138                4                  0
# 2                     120                4                  0
# 3                     102                3                  1
# 4                     138                4                  1
#
#    fasting_blood_sugar_gt_120_mg_per_dl  resting_ekg_results  \
# 0                                     0                    2
# 1                                     0                    0
# ...

# %%
print(data['max_heart_rate_diff'].min())
print(data['max_heart_rate_diff'].max())
# Out:
# 29
# 77

# %%
print(test['max_heart_rate_diff'].min())
print(test['max_heart_rate_diff'].max())
# Out:
# 34
# 76

# %%
data.heart_disease_present.value_counts()
# Out:
# 0    100
# 1     80
# Name: heart_disease_present, dtype: int64

# %%
merged = pd.concat([data, test], ignore_index = True)

# %%
merged.isnull().sum()
# Out:
# age                                      0
# chest_pain_type                          0
# exercise_induced_angina                  0
# fasting_blood_sugar_gt_120_mg_per_dl     0
# heart_disease_present                   90
# max_heart_rate_achieved                  0
# max_heart_rate_diff                      0
# num_major_vessels                        0
# oldpeak_eq_st_depression                 0
# patient_id                               0
# resting_blood_pressure                   0
# resting_ekg_results                      0
# serum_cholesterol_mg_per_dl              0
# sex                                      0
# slope_of_peak_exercise_st_segment        0
# thal                                     0
# dtype: int64

# %%
merged.iloc[175:190]
# Out:
#      age  chest_pain_type  exercise_induced_angina  \
# 175   67                4                        0
# 176   55                4                        1
# 177   64                3                        1
# 178   48                3                        0
# 179   54                3                        0
# 180   59                1                        0
# 181   35                4                        0
# 182   43                4                        1
# 183   60                3                        0
# 184   61                4                        1
# 185   43                3                        0
# 186   66                1                        0
# 187   69                3                        0
# 188   59                4                        0
# 189   47                3                        0
#
#      fasting_blood_sugar_gt_120_mg_per_dl  heart_disease_present  \
# 175                                     1                    1.0
# ...

# %%
#getting the minimum value in the age column
merged.age.min()
# Out:
# 29

# %%
#getting the maximum value in the age column
merged.age.max()
# Out:
# 77

# %%
#checking all the unique values in the age column
merged.age.unique()
# Out:
# array([45, 54, 77, 40, 59, 42, 60, 57, 50, 66, 64, 38, 29, 58, 71, 52, 67,
#        70, 68, 51, 41, 65, 53, 48, 62, 74, 61, 63, 46, 43, 56, 44, 35, 55,
#        49, 47, 37, 69, 39, 34, 76], dtype=int64)

# %%
merged.age.head()
# Out:
# 0    45
# 1    54
# 2    77
# 3    40
# 4    59
# Name: age, dtype: int64

# %%
#this creates categories for the age column form the lowest value upto the highest value and labels them from 0-9
merged.age = pd.cut(merged.age, bins=[0,40,60,100], labels=[1,2,3])

# %%
#gets the minimum value in the resting BP
merged.resting_blood_pressure.min()
# Out:
# 94

# %%
#gets the maximum value in the resting BP
merged.resting_blood_pressure.max()
# Out:
# 200

# %%
#getting the unique values in the resting BP column
merged.resting_blood_pressure.unique()
# Out:
# array([128, 110, 125, 152, 178, 130, 150, 170, 120, 140, 138, 144, 136,
#        160, 108, 106, 156, 180, 112, 122, 124, 135, 105, 115, 126, 172,
#        145, 118, 134, 100, 155, 132, 102,  94, 117, 142, 129, 158, 174,
#        101, 146, 104, 200, 192, 123, 165, 148], dtype=int64)

# %%
#this creates categories for the age column form 50 to 400, creating the categories in a specified way
merged.resting_blood_pressure = pd.cut(merged.resting_blood_pressure, bins=[0,110,140,201,400], labels=range(1,5))

# %%
merged.thal.unique()
# Out:
# array(['normal', 'reversible_defect', 'fixed_defect'], dtype=object)

# %%
#creates a dictionary that maps the keys to the values
mapper={'normal':1, 'reversible_defect':2, 'fixed_defect':3}

# maps the keys of the dict to the values
merged.thal=merged.thal.map(mapper)

# %%
#drops all the duplicate entries in the data
merged.drop_duplicates(keep='first',inplace=True)

# %%
#checks if there are any empty spaces in the data
merged.isnull().sum()
# Out:
# age                                      0
# chest_pain_type                          0
# exercise_induced_angina                  0
# fasting_blood_sugar_gt_120_mg_per_dl     0
# heart_disease_present                   90
# max_heart_rate_achieved                  0
# max_heart_rate_diff                      0
# num_major_vessels                        0
# oldpeak_eq_st_depression                 0
# patient_id                               0
# resting_blood_pressure                   0
# resting_ekg_results                      0
# serum_cholesterol_mg_per_dl              0
# sex                                      0
# slope_of_peak_exercise_st_segment        0
# thal                                     0
# dtype: int64

# %%
merged.serum_cholesterol_mg_per_dl = pd.cut(merged.serum_cholesterol_mg_per_dl, bins=[0,200,400,1000],labels=[1,2,3])

# %%
print(merged.max_heart_rate_diff.min())
print(merged.max_heart_rate_diff.max())
print(merged.max_heart_rate_diff.std())
print(merged.max_heart_rate_diff.mean())
# Out:
# 29
# 77
# 9.109066523898205
# 54.43333333333333

# %%
merged.max_heart_rate_diff = pd.cut(merged.max_heart_rate_diff, bins=[0,44,64,100],labels=[1,2,3])

# %%
merged.oldpeak_eq_st_depression = pd.cut(merged.oldpeak_eq_st_depression, bins=3, labels=[1,2,3])

# %%
merged.tail()
# Out:
#     age  chest_pain_type  exercise_induced_angina  \
# 265   2                3                        0
# 266   2                4                        1
# 267   2                1                        0
# 268   2                4                        1
# 269   2                4                        0
#
#      fasting_blood_sugar_gt_120_mg_per_dl  heart_disease_present  \
# 265                                     0                    NaN
# 266                                     0                    NaN
# 267                                     0                    NaN
# 268                                     0                    NaN
# 269                                     0                    NaN
#
#      max_heart_rate_achieved max_heart_rate_diff  num_major_vessels  \
# 265                      172                   2                  0
# 266                      125                   1                  0
# ...

# %%
merged.drop('max_heart_rate_achieved', axis=1, inplace=True)

# %%
data = merged.iloc[:180]
test = merged.iloc[180:]

# %%
data.tail()
# Out:
#     age  chest_pain_type  exercise_induced_angina  \
# 175   3                4                        0
# 176   2                4                        1
# 177   3                3                        1
# 178   2                3                        0
# 179   2                3                        0
#
#      fasting_blood_sugar_gt_120_mg_per_dl  heart_disease_present  \
# 175                                     1                    1.0
# 176                                     0                    1.0
# 177                                     0                    1.0
# 178                                     1                    0.0
# 179                                     0                    0.0
#
#     max_heart_rate_diff  num_major_vessels oldpeak_eq_st_depression  \
# 175                   3                  2                        1
# 176                   2                  0                        2
# ...

# %%
test.head()
# Out:
#     age  chest_pain_type  exercise_induced_angina  \
# 180   2                1                        0
# 181   1                4                        0
# 182   2                4                        1
# 183   2                3                        0
# 184   3                4                        1
#
#      fasting_blood_sugar_gt_120_mg_per_dl  heart_disease_present  \
# 180                                     0                    NaN
# 181                                     0                    NaN
# 182                                     0                    NaN
# 183                                     0                    NaN
# 184                                     0                    NaN
#
#     max_heart_rate_diff  num_major_vessels oldpeak_eq_st_depression  \
# 180                   2                  0                        1
# 181                   1                  0                        1
# ...

# %%
data.heart_disease_present = data.heart_disease_present.astype(int)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\generic.py:3643: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
data.isnull().sum()
# Out:
# age                                     0
# chest_pain_type                         0
# exercise_induced_angina                 0
# fasting_blood_sugar_gt_120_mg_per_dl    0
# heart_disease_present                   0
# max_heart_rate_diff                     0
# num_major_vessels                       0
# oldpeak_eq_st_depression                0
# patient_id                              0
# resting_blood_pressure                  0
# resting_ekg_results                     0
# serum_cholesterol_mg_per_dl             0
# sex                                     0
# slope_of_peak_exercise_st_segment       0
# thal                                    0
# dtype: int64

# %%
test.drop('heart_disease_present', axis=1, inplace=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test.isnull().sum()
# Out:
# age                                     0
# chest_pain_type                         0
# exercise_induced_angina                 0
# fasting_blood_sugar_gt_120_mg_per_dl    0
# max_heart_rate_diff                     0
# num_major_vessels                       0
# oldpeak_eq_st_depression                0
# patient_id                              0
# resting_blood_pressure                  0
# resting_ekg_results                     0
# serum_cholesterol_mg_per_dl             0
# sex                                     0
# slope_of_peak_exercise_st_segment       0
# thal                                    0
# dtype: int64

# %%
data.drop('patient_id', axis=1, inplace=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
#getting the target/labels for your predictions
y = data.heart_disease_present
y = y.values

# %%
#getting the features for yoyr predictions
X = data.drop('heart_disease_present', axis=1)

# %%
X = X.values

# %%
test.drop('patient_id',axis=1,inplace=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
test = test.values

# %%
#isntanciating the random forest classifier object
forest = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=2, min_samples_leaf=2)

# %%
forest.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=2, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=2, verbose=0,
#                        warm_start=False)

# %%
#making predictions
pred = forest.predict_proba(test)

# %%
pred[:,1][:5]
# Out:
# array([0.35129445, 0.19249618, 0.91473265, 0.08161143, 0.8591163 ])

# %%
sol = pd.read_csv('submission_format.csv')

# %%
sol['heart_disease_present'] = pred[:,1]

# %%
sol.to_csv('solution.csv', index=False)
